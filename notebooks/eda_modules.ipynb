# %%
import sys
import os
import pandas as pd
# Add the path to the script if it's not in the same directory
sys.path.append("../scripts")  # Adjust this path

from eda_module import EDAAnalyzer

# %% [markdown]
# ## Load The Data

# %%
df = pd.read_csv('../data/MachineLearningRating_v3.txt', delimiter='|', low_memory=False)

# %%
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
# Initialize the EDAAnalyzer
eda = EDAAnalyzer(df)

# %% [markdown]
# ## Data Summarization

# %% [markdown]
# #### Descriptive Statistics

# %%
# Descriptive statistics
df.describe()
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %%
df.dtypes
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %%
# Review data types
print(df.dtypes)
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %%
# 5.3 Assess data quality
eda.assess_data_quality()
# Out:
# Missing Values per Column:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Data Heatmap")
plt.show()

# %%
# Assuming 'df' is your DataFrame
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_percentage.sort_values(ascending=False, inplace=True)

# Display the result
print(missing_percentage)
# Out:
# NumberOfVehiclesInFleet     100.000000
# CrossBorder                  99.930207
# CustomValueEstimate          77.956560
# Rebuilt                      64.183810
# Converted                    64.183810
# WrittenOff                   64.183810
# NewVehicle                   15.327998
# Bank                         14.594670
# AccountType                   4.022806
# Gender                        0.953507
# MaritalStatus                 0.825819
# VehicleType                   0.055195
# make                          0.055195
# mmcode                        0.055195
# Model                         0.055195
# Cylinders                     0.055195
# bodytype                      0.055195
# kilowatts                     0.055195
# NumberOfDoors                 0.055195
# VehicleIntroDate              0.055195
# cubiccapacity                 0.055195
# CapitalOutstanding            0.000200
# SubCrestaZone                 0.000000
# ItemType                      0.000000
# ...

# %% [markdown]
# ### Missing Values Analysis
#
# #### **Columns with Large Amounts of Missing Data**
# The following columns have a significant proportion of missing values, potentially making them unsuitable for analysis without intervention:
# - **`NumberOfVehiclesInFleet`**: 100% missing
# - **`CrossBorder`**: 99.93% missing
# - **`CustomValueEstimate`**: 77.95% missing
# - **`WrittenOff`**: 64.18% missing
# - **`Converted`**: 64.18% missing
# - **`Rebuilt`**: 64.18% missing
#
# #### **Columns with Medium Amounts of Missing Data**
# Columns with moderate amounts of missing data that may require imputation or further exploration:
# - **`NewVehicle`**: 15.32% missing
# - **`Bank`**: 14.59% missing
# - **`AccountType`**: 4.02% missing
#
# #### **Columns with Insignificant Amounts of Missing Data**
# Columns with minimal missing values (<0.1%) that can be easily addressed through imputation:
# - **`Gender`**: 0.95%
# - **`MaritalStatus`**: 0.83%
# - **`VehicleType`**, **`make`**, **`mmcode`**, **`Model`**, **`Cylinders`**, **`bodytype`**, **`kilowatts`**, **`NumberOfDoors`**, **`VehicleIntroDate`**, **`cubiccapacity`**: ~0.06%
# - **`CapitalOutstanding`**: 0.0002%
#
# #### **Columns with Complete Data**
# The following columns have no missing values:
# - **`SubCrestaZone`**, **`ItemType`**, **`Province`**, **`StatutoryRiskType`**, **`TotalPremium`**, **`TotalClaims`**
#
# ---

# %% [markdown]
# # univariate analysis

# %%
eda.univariate_analysis()

# %%
# 5.5 Perform bivariate analysis
eda.bivariate_analysis()

# %%
# 5.6 Detect outliers
eda.outlier_detection()
# Out:
# Skipping column 'NumberOfVehiclesInFleet' as it contains no valid data.

# %%
# 5.7 Generate creative visualizations
eda.creative_visualizations()

# %% [markdown]
# **Summary of Findings:**
#
# The analysis of insurance claims data reveals critical insights into risk variations across different provinces and vehicle types:
#
# *   **Risk by Province:** Gauteng province exhibits the highest risk, with a disproportionately high claim ratio, followed by KwaZulu-Natal and Western Cape. In contrast, the Northern Cape presents a significantly lower risk.
#
# *   **Claims by Vehicle Type:** Heavy commercial vehicles account for the largest portion of total claim amounts, substantially exceeding the other vehicle categories. Medium commercial vehicles and passenger vehicles also contribute significantly to claim volumes, while light commercial vehicles and buses have lower total claims.

# %%
# Step 7: Get the processed DataFrame
processed_df = eda.get_processed_df()
